# %%
name=input("write  your name? ")
balance=float(input("Your current balance? "))

def printMenu():
    print(name,"Welcome to the atm")
    print(""""Pick from the following
          'b'(balance)
          'd'(deposit)
          'w'(withdraw)
          't'(transfer)
          'q'(quit)""")

def getTransaction():
    transaction=str(input("What would you like to do? "))
    return transaction

def withdraw(bal,amt):
    global balance
    balance=bal-amt
    if balance<0:
        print("you doun't have enough funds")


def formatCurrency(amt):
    return "SR%.2f" %amt


def transfer (bal,amt):
    global balance
    balance=bal-amt
    if balance<0:
        print("You dont have enoung funds for that: ")


printMenu()
command=str.lower((getTransaction()))

while command!="q":
    if (command=="b"):
        print(name,"Your current balance is",formatCurrency(balance))
        printMenu()
        command=str.lower((getTransaction()))
    elif (command=="d"):
        amount=float(input("Amount to deposit? "))
        balance=balance+amount
        print(balance)
        printMenu()
        command=str.lower((getTransaction()))
    elif (command=="w"):
        amount=float(input("Amount to withdraw? "))
        withdraw(balance,amount)
        print(balance)
        printMenu()
        command=str.lower((getTransaction()))
    elif (command=="t"):
        print("who would you like to transfer money too")
        Name =print (input("write here: "))
        amount = float(input("write here the amount that you will send: "))
        print(F"You will transfer {amount }sr ")
        transfer(balance,amount)
        print(balance)
        printMenu()
        command=str.lower((getTransaction()))
    else:
        print("Incorrect command. Please try again.")
        printMenu()
        command=str.lower((getTransaction()))

print(name,"Thank you for using this atm! See you again soon")
# Out:
# write  your name? tayam
# Your current balance? 2000
# tayam Welcome to the atm
# "Pick from the following
#           'b'(balance)
#           'd'(deposit)
#           'w'(withdraw)
#           't'(transfer)
#           'q'(quit)
# What would you like to do? B
# tayam Your current balance is SR2000.00
# tayam Welcome to the atm
# "Pick from the following
#           'b'(balance)
#           'd'(deposit)
#           'w'(withdraw)
#           't'(transfer)
#           'q'(quit)
# What would you like to do? q
# tayam Thank you for using this atm! See you again soon
